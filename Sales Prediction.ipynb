# %%
import pandas as pd
import numpy as np
import holidays
from fbprophet import Prophet

# %%
row_data = pd.read_csv('/Users/arty/dataset/sales.csv', sep=';', parse_dates=['date'])

# %%
row_data.head()
# Out:
#         date  sum_per_month  count_per_month
# 0 2018-01-01        1396690               30
# 1 2018-02-01         847090               21
# 2 2018-03-01        1306690               32
# 3 2018-04-01        1149520               24
# 4 2018-05-01        1610190               37

# %%
row_data.dtypes
# Out:
# date               datetime64[ns]
# sum_per_month               int64
# count_per_month             int64
# dtype: object

# %%
df = row_data[['date', 'sum_per_month']]

# %%
df.columns = ['ds', 'y']

# %%
df.tail()
# Out:
#            ds        y
# 26 2020-03-01  1079415
# 27 2020-04-01        0
# 28 2020-05-01        0
# 29 2020-06-01   562355
# 30 2020-07-01  1409270

# %%
holidays_dates = holidays.RU(years=(2015, 2016, 2017, 2018, 2019, 2020, 2021))
holidays_data = pd.DataFrame.from_dict(holidays_dates, orient='index').reset_index()
holidays_data.columns = ['ds', 'holiday']
holidays_data['ds'] = pd.to_datetime(holidays_data.ds)
holidays_data = holidays_data.sort_values(by=['ds'])
holidays_data = holidays_data.reset_index(drop=True)

# %%
predictions = 3

# %%
train_df = df[:-predictions]

# %%
df.tail()
# Out:
#            ds        y
# 26 2020-03-01  1079415
# 27 2020-04-01        0
# 28 2020-05-01        0
# 29 2020-06-01   562355
# 30 2020-07-01  1409270

# %%
m = Prophet(holidays=holidays_data, 
            daily_seasonality=False, 
            weekly_seasonality=True, 
            yearly_seasonality=False, 
            changepoints=['2020-01-04'])

m.fit(train_df)

# %%
future = m.make_future_dataframe(periods=predictions)
forecast = m.predict(future)

# %%
m.plot(forecast);

# %%
m.plot_components(forecast);

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
iplot([
    go.Scatter(x=df['ds'], y=df['y'], name='fact'),
    go.Scatter(x=forecast['ds'], y=forecast['yhat'], name='predictions'),
    go.Scatter(x=forecast['ds'], y=forecast['yhat_upper'], fill='tonexty', mode='none', name='upper'),
    go.Scatter(x=forecast['ds'], y=forecast['yhat_lower'], fill='tonexty', mode='none', name='lower'),
    go.Scatter(x=forecast['ds'], y=forecast['trend'], name='trend')
])
# Out:
# <div>                            <div id="1923d2db-f1ee-4830-a88a-934b3e7ad5ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1923d2db-f1ee-4830-a88a-934b3e7ad5ae")) {                    Plotly.newPlot(                        "1923d2db-f1ee-4830-a88a-934b3e7ad5ae",                        [{"name": "fact", "type": "scatter", "x": ["2018-01-01T00:00:00", "2018-02-01T00:00:00", "2018-03-01T00:00:00", "2018-04-01T00:00:00", "2018-05-01T00:00:00", "2018-06-01T00:00:00", "2018-07-01T00:00:00", "2018-08-01T00:00:00", "2018-09-01T00:00:00", "2018-10-01T00:00:00", "2018-11-01T00:00:00", "2018-12-01T00:00:00", "2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00"], "y": [1396690, 847090, 1306690, 1149520, 1610190, 931490, 1765120, 1741100, 1401500, 1654310, 1174870, 1601440, 1914310, 1200430, 1285580, 1328960, 1086910, 1177960, 1525500, 1702590, 1272120, 1230900, 1225410, 1102640, 1236130, 1718030, 1079415, 0, 0, 562355, 1409270]}, {"name": "predictions", "type": "scatter", "x": ["2018-01-01T00:00:00", "2018-02-01T00:00:00", "2018-03-01T00:00:00", "2018-04-01T00:00:00", "2018-05-01T00:00:00", "2018-06-01T00:00:00", "2018-07-01T00:00:00", "2018-08-01T00:00:00", "2018-09-01T00:00:00", "2018-10-01T00:00:00", "2018-11-01T00:00:00", "2018-12-01T00:00:00", "2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-04T00:00:00"], "y": [1724636.3551782044, 1309942.4369928325, 1303042.851135462, 1368258.2152760474, 1641184.2643376065, 1224506.5758672503, 1345834.5612401585, 1019790.4936131905, 1529025.7151314442, 1430921.844854572, 1242671.4748851166, 1506602.061095669, 1703874.4494340678, 1164135.1996163672, 1157235.6137593505, 1386074.5367828845, 1055901.5183721294, 1461754.7530241183, 1363650.8827474196, 1175400.51277757, 1240615.8769180398, 1410159.9391127361, 1096864.2375092932, 1218192.2228821507, 1118591.7034694438, 1401383.3767239552, 1195768.5687432163, 869724.5010607358, 1115029.136366581, 1058916.5151316838, 1385859.308430612]}, {"fill": "tonexty", "mode": "none", "name": "upper", "type": "scatter", "x": ["2018-01-01T00:00:00", "2018-02-01T00:00:00", "2018-03-01T00:00:00", "2018-04-01T00:00:00", "2018-05-01T00:00:00", "2018-06-01T00:00:00", "2018-07-01T00:00:00", "2018-08-01T00:00:00", "2018-09-01T00:00:00", "2018-10-01T00:00:00", "2018-11-01T00:00:00", "2018-12-01T00:00:00", "2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-04T00:00:00"], "y": [2139280.4777611666, 1721501.9560599884, 1718336.5186039112, 1717688.8908543102, 2054238.5538713085, 1586755.6307152305, 1729278.6400766561, 1407653.699205718, 1905904.2640482, 1822567.2379393633, 1615691.8869520319, 1894955.730362997, 2132905.60586592, 1536779 ...

# %%
cmp_df = forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(df.set_index('ds'))

# %%
cmp_df['e'] = cmp_df['y'] - cmp_df['yhat']
cmp_df['p'] = 100 * cmp_df['e'] / cmp_df['y']

# %%
# cmp_df[cmp_df.y == 0]

# %%
cmp_df.loc[~np.isfinite(cmp_df.p)] = np.nan
cmp_df = cmp_df.dropna()

# %%
# оценка качества
print(f'{round(np.mean(abs(cmp_df[-predictions:]["p"])))}% MAPE (mean absolute percentage error)')

# на сколько ошибается модель в абсолютных величинах
print(f'{round(np.mean(abs(cmp_df[-predictions:]["e"])))} MAE (mean absolute error)')
# Out:
# 13% MAPE (mean absolute percentage error)
# 183513 MAE (mean absolute error)

# %%
predicted_months = 3

# %%
final_train_df = df

# %%
f = Prophet(holidays=holidays_data, 
            daily_seasonality=False, 
            weekly_seasonality=True, 
            yearly_seasonality=False, 
            changepoints=['2020-01-04'])

f.fit(final_train_df)

# %%
final_future = f.make_future_dataframe(periods=predicted_months)
final_forecast = f.predict(final_future)

# %%
f.plot(final_forecast);

# %%
iplot([
    go.Scatter(x=df['ds'], y=df['y'], name='fact'),
    go.Scatter(x=final_forecast['ds'], y=final_forecast['yhat'], name='yhat'),
    go.Scatter(x=final_forecast['ds'], y=final_forecast['yhat_upper'], fill='tonexty', mode='none', name='upper'),
    go.Scatter(x=final_forecast['ds'], y=final_forecast['yhat_lower'], fill='tonexty', mode='none', name='lower'),
    go.Scatter(x=final_forecast['ds'], y=final_forecast['trend'], name='trend')
])
# Out:
# <div>                            <div id="292875bf-100d-4cf4-b515-a161d7649881" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("292875bf-100d-4cf4-b515-a161d7649881")) {                    Plotly.newPlot(                        "292875bf-100d-4cf4-b515-a161d7649881",                        [{"name": "fact", "type": "scatter", "x": ["2018-01-01T00:00:00", "2018-02-01T00:00:00", "2018-03-01T00:00:00", "2018-04-01T00:00:00", "2018-05-01T00:00:00", "2018-06-01T00:00:00", "2018-07-01T00:00:00", "2018-08-01T00:00:00", "2018-09-01T00:00:00", "2018-10-01T00:00:00", "2018-11-01T00:00:00", "2018-12-01T00:00:00", "2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00"], "y": [1396690, 847090, 1306690, 1149520, 1610190, 931490, 1765120, 1741100, 1401500, 1654310, 1174870, 1601440, 1914310, 1200430, 1285580, 1328960, 1086910, 1177960, 1525500, 1702590, 1272120, 1230900, 1225410, 1102640, 1236130, 1718030, 1079415, 0, 0, 562355, 1409270]}, {"name": "yhat", "type": "scatter", "x": ["2018-01-01T00:00:00", "2018-02-01T00:00:00", "2018-03-01T00:00:00", "2018-04-01T00:00:00", "2018-05-01T00:00:00", "2018-06-01T00:00:00", "2018-07-01T00:00:00", "2018-08-01T00:00:00", "2018-09-01T00:00:00", "2018-10-01T00:00:00", "2018-11-01T00:00:00", "2018-12-01T00:00:00", "2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-03T00:00:00", "2020-07-04T00:00:00"], "y": [1602499.6263169902, 1381472.8673691857, 1365115.8265789452, 1497826.8255701198, 1444753.7058296243, 1210973.3265477936, 1444666.4430012496, 1405294.1174029422, 1603453.8034522808, 1371680.5133855655, 1221991.719662599, 1550293.420883345, 1770517.6810392193, 1067849.2196307275, 1051492.1788405676, 1265359.7482475322, 848262.8527922462, 1443972.655745474, 1212199.3656794012, 1062510.5719558718, 1195221.5709468867, 1539698.5681093095, 908368.0719244925, 1142061.1883780167, 1174026.8280022938, 1300848.5487676929, 1088900.8056822238, 1049528.4800153368, 404497.1896204894, 1015914.8758617141, 996368.0972431725, 866226.0820698885, 765243.9646051065, 1210884.824076563]}, {"fill": "tonexty", "mode": "none", "name": "upper", "type": "scatter", "x": ["2018-01-01T00:00:00", "2018-02-01T00:00:00", "2018-03-01T00:00:00", "2018-04-01T00:00:00", "2018-05-01T00:00:00", "2018-06-01T00:00:00", "2018-07-01T00:00:00", "2018-08-01T00:00:00", "2018-09-01T00:00:00", "2018-10-01T00:00:00", "2018-11-01T00:00:00", "2018-12-01T00:00:00", "2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-03T00:00:00", "2020-07-04T00:00:00"], "y": [2042186.432538651, 1822624.8705208371, 1781092.412571954, 1933165.52004 ...

# %%
# final_forecast.to_excel("./app_forecast.xlsx", sheet_name='Data', index=False, encoding="cp1251")
